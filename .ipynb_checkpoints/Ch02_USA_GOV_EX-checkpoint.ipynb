# %%
import os
import json
import matplotlib as mlb
import numpy as np

# %%
# %matplotlib notebook

# %%
#get current working directory
cwd = os.getcwd()
print(cwd)
# Out:
# C:\Users\cfang\Documents\GitHub\Py_For_DataAnalysis

# %%
path = os.path.join(cwd,'ch02\\usagov_bitly_data2012-03-16-1331923249.txt')
# print(path)

# %%
records = [json.loads(line) for line in open(path)] #returns a dictionary

# %%
records[1]
# Out:
# {'a': 'GoogleMaps/RochesterNY',
#  'c': 'US',
#  'cy': 'Provo',
#  'g': 'mwszkS',
#  'gr': 'UT',
#  'h': 'mwszkS',
#  'hc': 1308262393,
#  'hh': 'j.mp',
#  'l': 'bitly',
#  'll': [40.218102, -111.613297],
#  'nk': 0,
#  'r': 'http://www.AwareMap.com/',
#  't': 1331923249,
#  'tz': 'America/Denver',
#  'u': 'http://www.monroecounty.gov/etc/911/rss.php'}

# %%
time_zones = [rec['tz'] for rec in records if 'tz' in rec]
print (time_zones[:10])
# Out:
# ['America/New_York', 'America/Denver', 'America/New_York', 'America/Sao_Paulo', 'America/New_York', 'America/New_York', 'Europe/Warsaw', '', '', '']

# %%
#Get Count Fuction
def get_count(sequence):
    counts = {}
    for x in sequence:
        if x in counts:
            counts[x]+=1
        else:
            counts[x]=1
    return counts

# %%
tz_count = get_count(time_zones)
type(tz_count)
# Out:
# dict

# %%
from collections import Counter

# %%
counts = Counter(time_zones)
counts.most_common(10)
# Out:
# [('America/New_York', 1251),
#  ('', 521),
#  ('America/Chicago', 400),
#  ('America/Los_Angeles', 382),
#  ('America/Denver', 191),
#  ('Europe/London', 74),
#  ('Asia/Tokyo', 37),
#  ('Pacific/Honolulu', 36),
#  ('Europe/Madrid', 35),
#  ('America/Sao_Paulo', 33)]

# %%
import pandas as pd

# %%
df = pd.DataFrame(records)
df['tz'].value_counts()[:10]
# Out:
# America/New_York       1251
#                         521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# Europe/London            74
# Asia/Tokyo               37
# Pacific/Honolulu         36
# Europe/Madrid            35
# America/Sao_Paulo        33
# Name: tz, dtype: int64

# %%
import nose.tools as nt #assert_equal 
import numpy.testing as nptest #assert_array_equal

# %%
clean_tz = df['tz'].fillna('Missing')
clean_tz[clean_tz==''] = 'Unknown'
clean_tz.value_counts()[:10]
# Out:
# America/New_York       1251
# Unknown                 521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# Missing                 120
# Europe/London            74
# Asia/Tokyo               37
# Pacific/Honolulu         36
# Europe/Madrid            35
# Name: tz, dtype: int64

# %%
clean_tz.value_counts()[:10].plot(kind='barh', rot=0, color='r')

# %%
results = pd.Series([x.split()[0] for x in df.a.dropna()])
results[:5]
# Out:
# 0               Mozilla/5.0
# 1    GoogleMaps/RochesterNY
# 2               Mozilla/4.0
# 3               Mozilla/5.0
# 4               Mozilla/5.0
# dtype: object

# %%
results.value_counts()[:10]
# Out:
# Mozilla/5.0                 2594
# Mozilla/4.0                  601
# GoogleMaps/RochesterNY       121
# Opera/9.80                    34
# TEST_INTERNET_AGENT           24
# GoogleProducer                21
# Mozilla/6.0                    5
# BlackBerry8520/5.0.0.681       4
# BlackBerry8520/5.0.0.592       3
# Dalvik/1.4.0                   3
# dtype: int64

# %%
df_a = df[df.a.notnull()]
print(df_a)
# Out:
#       _heartbeat_                                                  a  \
# 0             NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1             NaN                             GoogleMaps/RochesterNY
# 2             NaN  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# 3             NaN  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 4             NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 5             NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 6             NaN  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.1...
# 7             NaN  Mozilla/5.0 (Windows NT 6.1; rv:2.0.1) Gecko/2...
# 8             NaN  Opera/9.80 (X11; Linux zbov; U; en) Presto/2.1...
# 9             NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 10            NaN  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2)...
# 11            NaN  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10.4...
# 12            NaN  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2)...
# ...

# %%
op_sys = np.where(df_a.a.str.contains('Windows'),'Windows','Not Windows')
by_tz_os = df_a.groupby(['tz', op_sys])
agg_counts = by_tz_os.size().unstack().fillna(0)
agg_counts[:10]
# Out:
#                                 Not Windows  Windows
# tz
#                                       245.0    276.0
# Africa/Cairo                            0.0      3.0
# Africa/Casablanca                       0.0      1.0
# Africa/Ceuta                            0.0      2.0
# Africa/Johannesburg                     0.0      1.0
# Africa/Lusaka                           0.0      1.0
# America/Anchorage                       4.0      1.0
# America/Argentina/Buenos_Aires          1.0      0.0
# America/Argentina/Cordoba               0.0      1.0
# America/Argentina/Mendoza               0.0      1.0

# %%
indexer = agg_counts.sum(1).argsort()
indexer[0:10]
# Out:
# tz
#                                   24
# Africa/Cairo                      20
# Africa/Casablanca                 21
# Africa/Ceuta                      92
# Africa/Johannesburg               87
# Africa/Lusaka                     53
# America/Anchorage                 54
# America/Argentina/Buenos_Aires    57
# America/Argentina/Cordoba         26
# America/Argentina/Mendoza         55
# dtype: int64

# %%
count_subset = agg_counts.take(indexer)[-10:]
count_subset
# Out:
#                      Not Windows  Windows
# tz
# America/Sao_Paulo           13.0     20.0
# Europe/Madrid               16.0     19.0
# Pacific/Honolulu             0.0     36.0
# Asia/Tokyo                   2.0     35.0
# Europe/London               43.0     31.0
# America/Denver             132.0     59.0
# America/Los_Angeles        130.0    252.0
# America/Chicago            115.0    285.0
#                            245.0    276.0
# America/New_York           339.0    912.0

# %%
count_subset.plot(kind='barh', stacked=True)

# %%
normed_subset = count_subset.div(count_subset.sum(1), axis=0)
normed_subset.plot(kind='barh',stacked=True)
# Out:
# <img src="data:image/png;base64,..." width="1440">
